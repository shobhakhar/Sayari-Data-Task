# %%
# import libraries
import requests
import json
import pandas as pd
import numpy as np
from matplotlib.pyplot import figure
from pyvis.network import Network

# %%
# extracting json file that has information about company with company names
url = "https://firststop.sos.nd.gov/api/Records/businesssearch"

payload = json.dumps({
  "SEARCH_VALUE": "x",
  "STARTS_WITH_YN": "true",
  "ACTIVE_ONLY_YN": True
})
headers = {
  'authority': 'firststop.sos.nd.gov',
  'accept': '*/*',
  'accept-language': 'en-US,en;q=0.9',
  'authorization': 'undefined',
  'content-type': 'application/json',
  'cookie': 'ASP.NET_SessionId=za5t3mpcb3dgqw3wrk4usgw2',
  'origin': 'https://firststop.sos.nd.gov',
  'referer': 'https://firststop.sos.nd.gov/search/business',
  'sec-ch-ua': '"Chromium";v="104", " Not A;Brand";v="99", "Google Chrome";v="104"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}
response = requests.request("POST", url, headers=headers, data=payload)

# %%
data = json.loads(response.text)
data
# Out:
# {'template': [{'label': 'Form Info', 'id': 'TITLE'},
#   {'label': 'SOS Control ID#', 'id': 'RECORD_NUM'},
#   {'label': 'Status', 'id': 'STATUS'},
#   {'label': 'Standing', 'id': 'STANDING'},
#   {'label': 'Filing Date', 'id': 'FILING_DATE'}],
#  'rows': {'103327': {'SORT_INDEX': 0,
#    'TITLE': ['AKITA DRILLING USA CORP.', 'Corporation - Business - Foreign'],
#    'ID': 103327,
#    'FILING_DATE': '11/30/2010',
#    'RECORD_NUM': '0000103696',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '103679': {'SORT_INDEX': 1,
#    'TITLE': ['AKITA EQUIPMENT CORP.', 'Corporation - Business - Foreign'],
#    'ID': 103679,
#    'FILING_DATE': '12/17/2010',
#    'RECORD_NUM': '0000104048',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '144321': {'SORT_INDEX': 2,
#    'TITLE': ['ATOS HEALTHCARE SERVICES, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 144321,
#    'FILING_DATE': '03/10/2015',
#    'RECORD_NUM': '0000144694',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '144320': {'SORT_INDEX': 3,
#    'TITLE': ['ATOS IT OUTSOURCING SERVICES, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 144320,
#    'FILING_DATE': '03/10/2015',
#    'RECORD_NUM': '0000144693',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '289003': {'SORT_INDEX': 4,
#    'TITLE': ['Cirrata Partners Insurance Agency LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 289003,
#    'FILING_DATE': '11/26/2019',
#    'RECORD_NUM': '0002983026',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '165394': {'SORT_INDEX': 5,
#    'TITLE': ['COMCAST BROADBAND SECURITY, LLC (dba XFINITY HOME)',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 165394,
#    'FILING_DATE': '11/28/2017',
#    'RECORD_NUM': '0000165771',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '97654': {'SORT_INDEX': 6,
#    'TITLE': ['CONDUENT BUSINESS SERVICES, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 97654,
#    'FILING_DATE': '01/20/2010',
#    'RECORD_NUM': '0000098023',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '48426': {'SORT_INDEX': 7,
#    'TITLE': ['CONDUENT GOVERNMENT SYSTEMS, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 48426,
#    'FILING_DATE': '08/06/1996',
#    'RECORD_NUM': '0000048634',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '105993': {'SORT_INDEX': 8,
#    'TITLE': ['CONDUENT HR SERVICES, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 105993,
#    'FILING_DATE': '04/21/2011',
#    'RECORD_NUM': '0000106362',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '88279': {'SORT_INDEX': 9,
#    'TITLE': ['CONDUENT HUMAN RESOURCE SERVICES, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 88279,
#    'FILING_DATE': '08/14/2007',
#    'RECORD_NUM': '0000088647',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '38823': {'SORT_INDEX': 10,
#    'TITLE': ['CONDUENT STATE & LOCAL SOLUTIONS, INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 38823,
#    'FILING_DATE': '03/21/1995',
#    'RECORD_NUM': '0000039021',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '74479': {'SORT_INDEX': 11,
#    'TITLE': ['CONDUENT STATE HEALTHCARE, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 74479,
#    'FILING_DATE': '05/01/2003',
#    'RECORD_NUM': '0000074703',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '90557': {'SORT_INDEX': 12,
#    'TITLE': ['CONTRACT FREIGHTERS, INC.', 'Corporation - Business - Foreign'],
#    'ID': 90557,
#    'FILING_DATE': '01/30/2008',
#    'RECORD_NUM': '0000090925',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '169193': {'SORT_INDEX': 13,
#    'TITLE': ['GXO LOGISTICS SUPPLY CHAIN, INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 169193,
#    'FILING_DATE': '05/30/2018',
#    'RECORD_NUM': '0000169571',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '50106': {'SORT_INDEX': 14,
#    'TITLE': ['GXO Logistics Worldwide, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 50106,
#    'FILING_DATE': '04/19/2004',
#    'RECORD_NUM': '0000050314',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '31989': {'SORT_INDEX': 15,
#    'TITLE': ['MCKESSON MEDICAL-SURGICAL MEDIMART INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 31989,
#    'FILING_DATE': '04/22/1991',
#    'RECORD_NUM': '0000032178',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '153110': {'SORT_INDEX': 16,
#    'TITLE': ['Miller Underground, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 153110,
#    'FILING_DATE': '04/25/2016',
#    'RECORD_NUM': '0000153484',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '146367': {'SORT_INDEX': 17,
#    'TITLE': ['RingSquared Telecom LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 146367,
#    'FILING_DATE': '06/10/2015',
#    'RECORD_NUM': '0000146740',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '171478': {'SORT_INDEX': 18,
#    'TITLE': ['Voxtur Appraisal Services, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 171478,
#    'FILING_DATE': '09/24/2018',
#    'RECORD_NUM': '0000171856',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '281594': {'SORT_INDEX': 19,
#    'TITLE': ['Voxtur Services, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 281594,
#    'FILING_DATE': '07/18/2019',
#    'RECORD_NUM': '0002845261',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '319429': {'SORT_INDEX': 20,
#    'TITLE': ['X Diamond Partners, LLP',
#     'Limited Liability Partnership - Domestic'],
#    'ID': 319429,
#    'FILING_DATE': '07/30/2021',
#    'RECORD_NUM': '0005577759',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '244002': {'SORT_INDEX': 21,
#    'TITLE': ['X ELECTRIC', 'Trade Name'],
#    'ID': 244002,
#    'FILING_DATE': '05/19/2011',
#    'RECORD_NUM': '0000244382',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '336584': {'SORT_INDEX': 22,
#    'TITLE': ['X Golf Bismarck', 'Trade Name'],
#    'ID': 336584,
#    'FILING_DATE': '06/01/2022',
#    'RECORD_NUM': '0005891299',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '322123': {'SORT_INDEX': 23,
#    'TITLE': ['X Golf Minot', 'Trade Name'],
#    'ID': 322123,
#    'FILING_DATE': '09/23/2021',
#    'RECORD_NUM': '0005643099',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '329549': {'SORT_INDEX': 24,
#    'TITLE': ['X Realty LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 329549,
#    'FILING_DATE': '02/02/2022',
#    'RECORD_NUM': '0005781604',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '304760': {'SORT_INDEX': 25,
#    'TITLE': ['X REPUBLIC SALON LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 304760,
#    'FILING_DATE': '11/10/2020',
#    'RECORD_NUM': '0005326132',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '157286': {'SORT_INDEX': 26,
#    'TITLE': ['X S BROKERS INSURANCE AGENCY, INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 157286,
#    'FILING_DATE': '11/02/2016',
#    'RECORD_NUM': '0000157662',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '68357': {'SORT_INDEX': 27,
#    'TITLE': ['X2COMM, INC.', 'Corporation - Business - Foreign'],
#    'ID': 68357,
#    'FILING_DATE': '10/25/2001',
#    'RECORD_NUM': '0000068574',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '343679': {'SORT_INDEX': 28,
#    'TITLE': ['x2VA LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 343679,
#    'FILING_DATE': '09/09/2022',
#    'RECORD_NUM': '0006023395',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '315018': {'SORT_INDEX': 29,
#    'TITLE': ['XactlyOne Foundation', 'Corporation - Nonprofit - Foreign'],
#    'ID': 315018,
#    'FILING_DATE': '05/07/2021',
#    'RECORD_NUM': '0005510743',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '330579': {'SORT_INDEX': 30,
#    'TITLE': ['Xactus, LLC', 'Limited Liability Company - Business - Foreign'],
#    'ID': 330579,
#    'FILING_DATE': '02/16/2022',
#    'RECORD_NUM': '0005806191',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '41359': {'SORT_INDEX': 31,
#    'TITLE': ['XANADU PRODUCTS, L.L.C.',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 41359,
#    'FILING_DATE': '12/19/2003',
#    'RECORD_NUM': '0000041563',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '84218': {'SORT_INDEX': 32,
#    'TITLE': ['XANADU, LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 84218,
#    'FILING_DATE': '10/16/2006',
#    'RECORD_NUM': '0000084583',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '310991': {'SORT_INDEX': 33,
#    'TITLE': ['Xander Products & Service LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 310991,
#    'FILING_DATE': '03/03/2021',
#    'RECORD_NUM': '0005452393',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '332361': {'SORT_INDEX': 34,
#    'TITLE': ['XAP Corporation', 'Corporation - Business - Foreign'],
#    'ID': 332361,
#    'FILING_DATE': '03/22/2022',
#    'RECORD_NUM': '0005827829',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '265626': {'SORT_INDEX': 35,
#    'TITLE': ['XAPIC STUDIOS', 'Trade Name'],
#    'ID': 265626,
#    'FILING_DATE': '10/14/2016',
#    'RECORD_NUM': '0000266006',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '334862': {'SORT_INDEX': 36,
#    'TITLE': ['XB Investments, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 334862,
#    'FILING_DATE': '05/03/2022',
#    'RECORD_NUM': '0005869610',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '151536': {'SORT_INDEX': 37,
#    'TITLE': ['XCALIBER INTERNATIONAL LTD., L.L.C.',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 151536,
#    'FILING_DATE': '02/01/2016',
#    'RECORD_NUM': '0000151910',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '315704': {'SORT_INDEX': 38,
#    'TITLE': ['XCAST LABS, INC.', 'Corporation - Business - Foreign'],
#    'ID': 315704,
#    'FILING_DATE': '05/20/2021',
#    'RECORD_NUM': '0005521523',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '170568': {'SORT_INDEX': 39,
#    'TITLE': ['XCED AVIATION SERVICES, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 170568,
#    'FILING_DATE': '07/31/2018',
#    'RECORD_NUM': '0000170946',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '171651': {'SORT_INDEX': 40,
#    'TITLE': ['XCEL AG SOLUTIONS LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 171651,
#    'FILING_DATE': '10/04/2018',
#    'RECORD_NUM': '0000172029',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '165755': {'SORT_INDEX': 41,
#    'TITLE': ['XCEL AGRONOMY LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 165755,
#    'FILING_DATE': '12/18/2017',
#    'RECORD_NUM': '0000166132',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '278291': {'SORT_INDEX': 42,
#    'TITLE': ['Xcel Automation', 'Trade Name'],
#    'ID': 278291,
#    'FILING_DATE': '04/16/2019',
#    'RECORD_NUM': '0002769937',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '278153': {'SORT_INDEX': 43,
#    'TITLE': ['Xcel Automation & Electric LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 278153,
#    'FILING_DATE': '04/16/2019',
#    'RECORD_NUM': '0002767465',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '324145': {'SORT_INDEX': 44,
#    'TITLE': ['Xcel Aviation', 'Trade Name'],
#    'ID': 324145,
#    'FILING_DATE': '10/26/2021',
#    'RECORD_NUM': '0005675460',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '333316': {'SORT_INDEX': 45,
#    'TITLE': ['Xcel Aviation LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 333316,
#    'FILING_DATE': '04/05/2022',
#    'RECORD_NUM': '0005852398',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '236957': {'SORT_INDEX': 46,
#    'TITLE': ['XCEL ENERGY', 'Trade Name'],
#    'ID': 236957,
#    'FILING_DATE': '01/30/2009',
#    'RECORD_NUM': '0000237337',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '83': {'SORT_INDEX': 47,
#    'TITLE': ['XCEL ENERGY INC.', 'Corporation - Business - Foreign'],
#    'ID': 83,
#    'FILING_DATE': '08/18/1910',
#    'RECORD_NUM': '0000000120',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '64528': {'SORT_INDEX': 48,
#    'TITLE': ['XCEL ENERGY SERVICES INC.', 'Corporation - Business - Foreign'],
#    'ID': 64528,
#    'FILING_DATE': '04/18/2001',
#    'RECORD_NUM': '0000064741',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '1940': {'SORT_INDEX': 49,
#    'TITLE': ['XCEL ERECTORS, INC.', 'Corporation - Business - Foreign'],
#    'ID': 1940,
#    'FILING_DATE': '11/14/1985',
#    'RECORD_NUM': '0000002063',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '330716': {'SORT_INDEX': 50,
#    'TITLE': ['Xcel Holdings', 'Trade Name'],
#    'ID': 330716,
#    'FILING_DATE': '02/28/2022',
#    'RECORD_NUM': '0005807728',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '333311': {'SORT_INDEX': 51,
#    'TITLE': ['Xcel Holdings LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 333311,
#    'FILING_DATE': '04/05/2022',
#    'RECORD_NUM': '0005852383',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '171445': {'SORT_INDEX': 52,
#    'TITLE': ['XCEL NDT LLC', 'Limited Liability Company - Business - Foreign'],
#    'ID': 171445,
#    'FILING_DATE': '09/04/2018',
#    'RECORD_NUM': '0000171823',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '311235': {'SORT_INDEX': 53,
#    'TITLE': ['Xcel Protective Services, Inc.',
#     'Corporation - Business - Foreign'],
#    'ID': 311235,
#    'FILING_DATE': '03/05/2021',
#    'RECORD_NUM': '0005455239',
#    'STATUS': 'Active',
#    'STANDING': 'Not Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '111653': {'SORT_INDEX': 54,
#    'TITLE': ['XCEL TRUCKING LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 111653,
#    'FILING_DATE': '11/09/2011',
#    'RECORD_NUM': '0000112023',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '180654': {'SORT_INDEX': 55,
#    'TITLE': ['XCELL DRIVING SCHOOL LLP',
#     'Limited Liability Partnership - Domestic'],
#    'ID': 180654,
#    'FILING_DATE': '08/27/2003',
#    'RECORD_NUM': '0000181034',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '108164': {'SORT_INDEX': 56,
#    'TITLE': ['XCHANGE BENEFITS, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 108164,
#    'FILING_DATE': '07/18/2011',
#    'RECORD_NUM': '0000108533',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '339752': {'SORT_INDEX': 57,
#    'TITLE': ['XCHANGE TELECOM LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 339752,
#    'FILING_DATE': '07/01/2022',
#    'RECORD_NUM': '0005927138',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '279055': {'SORT_INDEX': 58,
#    'TITLE': ['XCL AssetCo, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 279055,
#    'FILING_DATE': '05/02/2019',
#    'RECORD_NUM': '0002784591',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '302160': {'SORT_INDEX': 59,
#    'TITLE': ['XCL Marketing, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 302160,
#    'FILING_DATE': '09/18/2020',
#    'RECORD_NUM': '0005247897',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '278418': {'SORT_INDEX': 60,
#    'TITLE': ['XCL Resources, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 278418,
#    'FILING_DATE': '04/18/2019',
#    'RECORD_NUM': '0002772084',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '288834': {'SORT_INDEX': 61,
#    'TITLE': ['XCL RoyaltyCo, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 288834,
#    'FILING_DATE': '11/20/2019',
#    'RECORD_NUM': '0002981591',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '305451': {'SORT_INDEX': 62,
#    'TITLE': ['XCLOUD, LLC', 'Limited Liability Company - Business - Foreign'],
#    'ID': 305451,
#    'FILING_DATE': '11/20/2020',
#    'RECORD_NUM': '0005338314',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '279897': {'SORT_INDEX': 63,
#    'TITLE': ['Xclusive Apparel', 'Fictitious Partnership Name'],
#    'ID': 279897,
#    'FILING_DATE': '06/08/2019',
#    'RECORD_NUM': '0002797909',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '338193': {'SORT_INDEX': 64,
#    'TITLE': ['XCMG America Financial LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 338193,
#    'FILING_DATE': '06/23/2022',
#    'RECORD_NUM': '0005922092',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '141236': {'SORT_INDEX': 65,
#    'TITLE': ['XConnect, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 141236,
#    'FILING_DATE': '10/27/2014',
#    'RECORD_NUM': '0000141609',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '344030': {'SORT_INDEX': 66,
#    'TITLE': ['XCS Pros', 'Trade Name'],
#    'ID': 344030,
#    'FILING_DATE': '09/16/2022',
#    'RECORD_NUM': '0006028885',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '344027': {'SORT_INDEX': 67,
#    'TITLE': ['XCS Pros, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 344027,
#    'FILING_DATE': '09/16/2022',
#    'RECORD_NUM': '0006028866',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '335425': {'SORT_INDEX': 68,
#    'TITLE': ['xDatak LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 335425,
#    'FILING_DATE': '05/12/2022',
#    'RECORD_NUM': '0005876954',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '314011': {'SORT_INDEX': 69,
#    'TITLE': ['XDP Digital LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 314011,
#    'FILING_DATE': '04/22/2021',
#    'RECORD_NUM': '0005499495',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '274036': {'SORT_INDEX': 70,
#    'TITLE': ['Xe USA', 'Trade Name'],
#    'ID': 274036,
#    'FILING_DATE': '01/24/2019',
#    'RECORD_NUM': '0002695525',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '169122': {'SORT_INDEX': 71,
#    'TITLE': ['Xebec Systems USA LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 169122,
#    'FILING_DATE': '05/24/2018',
#    'RECORD_NUM': '0000169500',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '333730': {'SORT_INDEX': 72,
#    'TITLE': ['XEBU, LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 333730,
#    'FILING_DATE': '04/11/2022',
#    'RECORD_NUM': '0005857300',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '313973': {'SORT_INDEX': 73,
#    'TITLE': ['XeCare LLC', 'Limited Liability Company - Business - Foreign'],
#    'ID': 313973,
#    'FILING_DATE': '04/22/2021',
#    'RECORD_NUM': '0005499136',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '282675': {'SORT_INDEX': 74,
#    'TITLE': ['Xencom Energy Management, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 282675,
#    'FILING_DATE': '07/31/2019',
#    'RECORD_NUM': '0002859472',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '135134': {'SORT_INDEX': 75,
#    'TITLE': ['Xenex Disinfection Services Inc.',
#     'Corporation - Business - Foreign'],
#    'ID': 135134,
#    'FILING_DATE': '03/20/2014',
#    'RECORD_NUM': '0000135506',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '154726': {'SORT_INDEX': 76,
#    'TITLE': ['XENITH, LLC', 'Limited Liability Company - Business - Foreign'],
#    'ID': 154726,
#    'FILING_DATE': '06/27/2016',
#    'RECORD_NUM': '0000155100',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '148120': {'SORT_INDEX': 77,
#    'TITLE': ['XERCOR INSURANCE SERVICES LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 148120,
#    'FILING_DATE': '08/17/2015',
#    'RECORD_NUM': '0000148493',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '275237': {'SORT_INDEX': 78,
#    'TITLE': ['Xeris Pharmaceuticals, Inc.',
#     'Corporation - Business - Foreign'],
#    'ID': 275237,
#    'FILING_DATE': '02/14/2019',
#    'RECORD_NUM': '0002705646',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '17447': {'SORT_INDEX': 79,
#    'TITLE': ['XEROX CORPORATION', 'Corporation - Business - Foreign'],
#    'ID': 17447,
#    'FILING_DATE': '05/05/1964',
#    'RECORD_NUM': '0000017597',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '73374': {'SORT_INDEX': 80,
#    'TITLE': ['XEROX FINANCIAL SERVICES LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 73374,
#    'FILING_DATE': '02/04/2003',
#    'RECORD_NUM': '0000073595',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '62403': {'SORT_INDEX': 81,
#    'TITLE': ['XETA TECHNOLOGIES, INC.', 'Corporation - Business - Foreign'],
#    'ID': 62403,
#    'FILING_DATE': '04/06/2000',
#    'RECORD_NUM': '0000062616',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '269798': {'SORT_INDEX': 82,
#    'TITLE': ['XFINITY HOME', 'Trade Name'],
#    'ID': 269798,
#    'FILING_DATE': '11/28/2017',
#    'RECORD_NUM': '0000270178',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '100168': {'SORT_INDEX': 83,
#    'TITLE': ['X-GEN PHARMACEUTICALS, INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 100168,
#    'FILING_DATE': '06/19/2010',
#    'RECORD_NUM': '0000100537',
#    'STATUS': 'Active',
#    'STANDING': 'Not Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '117057': {'SORT_INDEX': 84,
#    'TITLE': ['XGP PROPERTIES, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 117057,
#    'FILING_DATE': '05/21/2012',
#    'RECORD_NUM': '0000117427',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '14868': {'SORT_INDEX': 85,
#    'TITLE': ['XH, LLC', 'Limited Liability Company - Business - Foreign'],
#    'ID': 14868,
#    'FILING_DATE': '05/04/1983',
#    'RECORD_NUM': '0000015018',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '74042': {'SORT_INDEX': 86,
#    'TITLE': ['XIE XIE, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 74042,
#    'FILING_DATE': '03/28/2003',
#    'RECORD_NUM': '0000074263',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '337322': {'SORT_INDEX': 87,
#    'TITLE': ['XILAJU, LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 337322,
#    'FILING_DATE': '06/09/2022',
#    'RECORD_NUM': '0005914329',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '136423': {'SORT_INDEX': 88,
#    'TITLE': ['XIPHOS TECHNICAL SERVICES, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 136423,
#    'FILING_DATE': '05/12/2014',
#    'RECORD_NUM': '0000136795',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '333154': {'SORT_INDEX': 89,
#    'TITLE': ['XIULING INC', 'Corporation - Business - Domestic'],
#    'ID': 333154,
#    'FILING_DATE': '04/01/2022',
#    'RECORD_NUM': '0005851059',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '326725': {'SORT_INDEX': 90,
#    'TITLE': ['Xkulsiv Kickz LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 326725,
#    'FILING_DATE': '12/13/2021',
#    'RECORD_NUM': '0005732815',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '293283': {'SORT_INDEX': 91,
#    'TITLE': ['XL Farms', 'Trade Name'],
#    'ID': 293283,
#    'FILING_DATE': '03/04/2020',
#    'RECORD_NUM': '0003069778',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '47640': {'SORT_INDEX': 92,
#    'TITLE': ['XL HOMES, CORP.', 'Corporation - Business - Domestic'],
#    'ID': 47640,
#    'FILING_DATE': '05/24/1996',
#    'RECORD_NUM': '0000047848',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '136264': {'SORT_INDEX': 93,
#    'TITLE': ['XL INDUSTRIAL SERVICES, INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 136264,
#    'FILING_DATE': '05/06/2014',
#    'RECORD_NUM': '0000136636',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '290974': {'SORT_INDEX': 94,
#    'TITLE': ['XL LOGISTICS LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 290974,
#    'FILING_DATE': '01/13/2020',
#    'RECORD_NUM': '0003016450',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '123072': {'SORT_INDEX': 95,
#    'TITLE': ['XL TRANSPORT, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 123072,
#    'FILING_DATE': '12/04/2012',
#    'RECORD_NUM': '0000123442',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '294747': {'SORT_INDEX': 96,
#    'TITLE': ['XLHome, P.C. (dba Home Health Assessments of North Dakota, P.C.)',
#     'Corporation - Professional - Foreign'],
#    'ID': 294747,
#    'FILING_DATE': '04/07/2020',
#    'RECORD_NUM': '0003118500',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '280171': {'SORT_INDEX': 97,
#    'TITLE': ['XLT Management Services, Inc.',
#     'Corporation - Business - Foreign'],
#    'ID': 280171,
#    'FILING_DATE': '05/29/2019',
#    'RECORD_NUM': '0002813336',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '270532': {'SORT_INDEX': 98,
#    'TITLE': ['XLT TAXI', 'Trade Name'],
#    'ID': 270532,
#    'FILING_DATE': '02/21/2018',
#    'RECORD_NUM': '0000270912',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '280560': {'SORT_INDEX': 99,
#    'TITLE': ['XLT Transport', 'Trade Name'],
#    'ID': 280560,
#    'FILING_DATE': '06/07/2019',
#    'RECORD_NUM': '0002831383',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '328530': {'SORT_INDEX': 100,
#    'TITLE': ['XLXF LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 328530,
#    'FILING_DATE': '01/24/2022',
#    'RECORD_NUM': '0005769264',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '316181': {'SORT_INDEX': 101,
#    'TITLE': ['XM ACRES, LLP', 'Limited Liability Partnership - Domestic'],
#    'ID': 316181,
#    'FILING_DATE': '05/28/2021',
#    'RECORD_NUM': '0005525442',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '343629': {'SORT_INDEX': 102,
#    'TITLE': ['XM42', 'Trade Name'],
#    'ID': 343629,
#    'FILING_DATE': '09/08/2022',
#    'RECORD_NUM': '0006023021',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '279692': {'SORT_INDEX': 103,
#    'TITLE': ['xmodn security LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 279692,
#    'FILING_DATE': '05/15/2019',
#    'RECORD_NUM': '0002794925',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '85802': {'SORT_INDEX': 104,
#    'TITLE': ['XN FINANCIAL SERVICES INC.', 'Corporation - Business - Foreign'],
#    'ID': 85802,
#    'FILING_DATE': '02/06/2007',
#    'RECORD_NUM': '0000086167',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '270408': {'SORT_INDEX': 105,
#    'TITLE': ['XO BEAUTY', 'Trade Name'],
#    'ID': 270408,
#    'FILING_DATE': '02/06/2018',
#    'RECORD_NUM': '0000270788',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '66466': {'SORT_INDEX': 106,
#    'TITLE': ['XO COMMUNICATIONS SERVICES, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 66466,
#    'FILING_DATE': '08/13/2004',
#    'RECORD_NUM': '0000066683',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '335837': {'SORT_INDEX': 107,
#    'TITLE': ['XO SKINCARE LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 335837,
#    'FILING_DATE': '05/19/2022',
#    'RECORD_NUM': '0005884093',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '116177': {'SORT_INDEX': 108,
#    'TITLE': ['XOME FIELD SERVICES LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 116177,
#    'FILING_DATE': '06/25/2014',
#    'RECORD_NUM': '0000116547',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '125299': {'SORT_INDEX': 109,
#    'TITLE': ['XOME INC.', 'Corporation - Business - Foreign'],
#    'ID': 125299,
#    'FILING_DATE': '03/05/2013',
#    'RECORD_NUM': '0000125669',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '123678': {'SORT_INDEX': 110,
#    'TITLE': ['XOME REALTY SERVICES LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 123678,
#    'FILING_DATE': '01/11/2013',
#    'RECORD_NUM': '0000124048',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '273234': {'SORT_INDEX': 111,
#    'TITLE': ['XOME VALUATIONS', 'Trade Name'],
#    'ID': 273234,
#    'FILING_DATE': '10/29/2018',
#    'RECORD_NUM': '0000273614',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '315910': {'SORT_INDEX': 112,
#    'TITLE': ['XOXO L.L.C.', 'Limited Liability Company - Business - Domestic'],
#    'ID': 315910,
#    'FILING_DATE': '05/26/2021',
#    'RECORD_NUM': '0005523477',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '323422': {'SORT_INDEX': 113,
#    'TITLE': ['XOXO, PHOENIIX LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 323422,
#    'FILING_DATE': '10/13/2021',
#    'RECORD_NUM': '0005664534',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '49020': {'SORT_INDEX': 114,
#    'TITLE': ['XP SYSTEMS CORPORATION', 'Corporation - Business - Foreign'],
#    'ID': 49020,
#    'FILING_DATE': '01/20/1999',
#    'RECORD_NUM': '0000049228',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '309601': {'SORT_INDEX': 115,
#    'TITLE': ['Xperience Barbers', 'Trade Name'],
#    'ID': 309601,
#    'FILING_DATE': '02/09/2021',
#    'RECORD_NUM': '0005432375',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '333623': {'SORT_INDEX': 116,
#    'TITLE': ['Xperience Barbers LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 333623,
#    'FILING_DATE': '04/19/2022',
#    'RECORD_NUM': '0005856034',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '231746': {'SORT_INDEX': 117,
#    'TITLE': ['XPERIENCE HEALTH & FITNESS', 'Trade Name'],
#    'ID': 231746,
#    'FILING_DATE': '07/24/2006',
#    'RECORD_NUM': '0000232126',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '86448': {'SORT_INDEX': 118,
#    'TITLE': ['XPERIENCE HEALTH & FITNESS LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 86448,
#    'FILING_DATE': '04/17/2007',
#    'RECORD_NUM': '0000086814',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '304915': {'SORT_INDEX': 119,
#    'TITLE': ['Xperience Title, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 304915,
#    'FILING_DATE': '11/06/2020',
#    'RECORD_NUM': '0005328786',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '282517': {'SORT_INDEX': 120,
#    'TITLE': ['Xpert Drywall llc',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 282517,
#    'FILING_DATE': '08/08/2019',
#    'RECORD_NUM': '0002857167',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '154896': {'SORT_INDEX': 121,
#    'TITLE': ['XPERT ENTERPRISES LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 154896,
#    'FILING_DATE': '07/01/2016',
#    'RECORD_NUM': '0000155270',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '291576': {'SORT_INDEX': 122,
#    'TITLE': ['Xpert Xteriors, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 291576,
#    'FILING_DATE': '01/28/2020',
#    'RECORD_NUM': '0003036205',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '107567': {'SORT_INDEX': 123,
#    'TITLE': ['XPI LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 107567,
#    'FILING_DATE': '06/20/2011',
#    'RECORD_NUM': '0000107936',
# ...
#    'ID': 275471,
#    'FILING_DATE': '02/20/2019',
#    'RECORD_NUM': '0002708816',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '310465': {'SORT_INDEX': 146,
#    'TITLE': ['XTDIRECT, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 310465,
#    'FILING_DATE': '02/24/2021',
#    'RECORD_NUM': '0005445845',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '157057': {'SORT_INDEX': 147,
#    'TITLE': ['X-TECH LLC', 'Limited Liability Company - Business - Foreign'],
#    'ID': 157057,
#    'FILING_DATE': '10/19/2016',
#    'RECORD_NUM': '0000157433',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '308363': {'SORT_INDEX': 148,
#    'TITLE': ['X-terior Solutions', 'Trade Name'],
#    'ID': 308363,
#    'FILING_DATE': '02/22/2021',
#    'RECORD_NUM': '0005407945',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '76644': {'SORT_INDEX': 149,
#    'TITLE': ['XTO ENERGY INC.', 'Corporation - Business - Foreign'],
#    'ID': 76644,
#    'FILING_DATE': '05/29/2008',
#    'RECORD_NUM': '0000076872',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '171952': {'SORT_INDEX': 150,
#    'TITLE': ['XTO HOLDINGS, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 171952,
#    'FILING_DATE': '10/02/2018',
#    'RECORD_NUM': '0000172330',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '13614': {'SORT_INDEX': 151,
#    'TITLE': ['XTO OFFSHORE INC.', 'Corporation - Business - Foreign'],
#    'ID': 13614,
#    'FILING_DATE': '12/18/1980',
#    'RECORD_NUM': '0000013762',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '269393': {'SORT_INDEX': 152,
#    'TITLE': ['XTOP LANGUAGE EDUCATION SERVICES', 'Trade Name'],
#    'ID': 269393,
#    'FILING_DATE': '10/18/2017',
#    'RECORD_NUM': '0000269773',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '169542': {'SORT_INDEX': 153,
#    'TITLE': ['XTRA APPAREL CO LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 169542,
#    'FILING_DATE': '06/14/2018',
#    'RECORD_NUM': '0000169920',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '77127': {'SORT_INDEX': 154,
#    'TITLE': ['XTRA PROPERTIES, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 77127,
#    'FILING_DATE': '10/11/2004',
#    'RECORD_NUM': '0000077355',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '195444': {'SORT_INDEX': 155,
#    'TITLE': ['XTRALIGHT MANUFACTURING LP', 'Fictitious Partnership Name'],
#    'ID': 195444,
#    'FILING_DATE': '08/26/2013',
#    'RECORD_NUM': '0000195824',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '273964': {'SORT_INDEX': 156,
#    'TITLE': ['Xtra-Office, Inc.', 'Corporation - Business - Domestic'],
#    'ID': 273964,
#    'FILING_DATE': '01/22/2019',
#    'RECORD_NUM': '0002694720',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '333362': {'SORT_INDEX': 157,
#    'TITLE': ['Xtravagant Elegance', 'Trade Name'],
#    'ID': 333362,
#    'FILING_DATE': '04/05/2022',
#    'RECORD_NUM': '0005852807',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '337680': {'SORT_INDEX': 158,
#    'TITLE': ['Xtreme Auto Detailz', 'Trade Name'],
#    'ID': 337680,
#    'FILING_DATE': '06/15/2022',
#    'RECORD_NUM': '0005917675',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '83121': {'SORT_INDEX': 159,
#    'TITLE': ['XTREME AUTO, INC.', 'Corporation - Business - Domestic'],
#    'ID': 83121,
#    'FILING_DATE': '06/28/2006',
#    'RECORD_NUM': '0000083485',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '236958': {'SORT_INDEX': 160,
#    'TITLE': ['XTREME BUILDERS', 'Trade Name'],
#    'ID': 236958,
#    'FILING_DATE': '01/27/2009',
#    'RECORD_NUM': '0000237338',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '309214': {'SORT_INDEX': 161,
#    'TITLE': ['Xtreme Carpet Cleaning LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 309214,
#    'FILING_DATE': '02/02/2021',
#    'RECORD_NUM': '0005427601',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '309089': {'SORT_INDEX': 162,
#    'TITLE': ['X-treme Detailing', 'Trade Name'],
#    'ID': 309089,
#    'FILING_DATE': '02/01/2021',
#    'RECORD_NUM': '0005426033',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '333710': {'SORT_INDEX': 163,
#    'TITLE': ['X-treme Detailing llc',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 333710,
#    'FILING_DATE': '04/08/2022',
#    'RECORD_NUM': '0005856910',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '92327': {'SORT_INDEX': 164,
#    'TITLE': ['XTREME DRILLING, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 92327,
#    'FILING_DATE': '06/17/2008',
#    'RECORD_NUM': '0000092696',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '79268': {'SORT_INDEX': 165,
#    'TITLE': ['XTREME ELECTRIC INC', 'Corporation - Business - Domestic'],
#    'ID': 79268,
#    'FILING_DATE': '01/14/2008',
#    'RECORD_NUM': '0000079498',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '106570': {'SORT_INDEX': 166,
#    'TITLE': ['XTREME ELECTRICAL SERVICES, INC. (dba X ELECTRIC)',
#     'Corporation - Business - Foreign'],
#    'ID': 106570,
#    'FILING_DATE': '05/19/2011',
#    'RECORD_NUM': '0000106939',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '108148': {'SORT_INDEX': 167,
#    'TITLE': ['XTREME FIRE PROTECTION, LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 108148,
#    'FILING_DATE': '07/13/2011',
#    'RECORD_NUM': '0000108517',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '154348': {'SORT_INDEX': 168,
#    'TITLE': ['X-TREME FITNESS, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 154348,
#    'FILING_DATE': '06/17/2016',
#    'RECORD_NUM': '0000154722',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '337553': {'SORT_INDEX': 169,
#    'TITLE': ['Xtreme installation LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 337553,
#    'FILING_DATE': '06/23/2022',
#    'RECORD_NUM': '0005916425',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '318390': {'SORT_INDEX': 170,
#    'TITLE': ['Xtreme installations', 'Trade Name'],
#    'ID': 318390,
#    'FILING_DATE': '07/07/2021',
#    'RECORD_NUM': '0005565360',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '319902': {'SORT_INDEX': 171,
#    'TITLE': ['XTREME INVESTMENTS INC', 'Corporation - Business - Domestic'],
#    'ID': 319902,
#    'FILING_DATE': '08/03/2021',
#    'RECORD_NUM': '0005583847',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '259434': {'SORT_INDEX': 172,
#    'TITLE': ['XTREME LIGHTING', 'Trade Name'],
#    'ID': 259434,
#    'FILING_DATE': '03/02/2015',
#    'RECORD_NUM': '0000259814',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '228979': {'SORT_INDEX': 173,
#    'TITLE': ['X-TREME OUTFITTERS', 'Trade Name'],
#    'ID': 228979,
#    'FILING_DATE': '03/02/2005',
#    'RECORD_NUM': '0000229359',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '132687': {'SORT_INDEX': 174,
#    'TITLE': ['XTREME PRODUCTS LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 132687,
#    'FILING_DATE': '12/09/2013',
#    'RECORD_NUM': '0000133058',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '231461': {'SORT_INDEX': 175,
#    'TITLE': ['XTREME SIGNS & GRAPHIX', 'Trade Name'],
#    'ID': 231461,
#    'FILING_DATE': '06/13/2006',
#    'RECORD_NUM': '0000231841',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '319007': {'SORT_INDEX': 176,
#    'TITLE': ['Xtreme Transport Logistics LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 319007,
#    'FILING_DATE': '07/22/2021',
#    'RECORD_NUM': '0005572886',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '240582': {'SORT_INDEX': 177,
#    'TITLE': ['XTREME TROPHY PROPERTIES', 'Trade Name'],
#    'ID': 240582,
#    'FILING_DATE': '05/20/2010',
#    'RECORD_NUM': '0000240962',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '278474': {'SORT_INDEX': 178,
#    'TITLE': ['Xtreme Xteriors LLC',
#     'Limited Liability Company - Business - Foreign'],
#    'ID': 278474,
#    'FILING_DATE': '05/02/2019',
#    'RECORD_NUM': '0002772735',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '323712': {'SORT_INDEX': 179,
#    'TITLE': ['XTS Holdings, LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 323712,
#    'FILING_DATE': '10/18/2021',
#    'RECORD_NUM': '0005668778',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '100169': {'SORT_INDEX': 180,
#    'TITLE': ['XTTRIUM LABORATORIES, INC.', 'Corporation - Business - Foreign'],
#    'ID': 100169,
#    'FILING_DATE': '06/19/2010',
#    'RECORD_NUM': '0000100538',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '9739': {'SORT_INDEX': 181,
#    'TITLE': ['XXI CENTURY LTD.', 'Corporation - Business - Domestic'],
#    'ID': 9739,
#    'FILING_DATE': '08/21/1987',
#    'RECORD_NUM': '0000009887',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '138231': {'SORT_INDEX': 182,
#    'TITLE': ['XYLEM DEWATERING SOLUTIONS, INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 138231,
#    'FILING_DATE': '08/01/2014',
#    'RECORD_NUM': '0000138604',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '111130': {'SORT_INDEX': 183,
#    'TITLE': ['XYLEM WATER SOLUTIONS U.S.A., INC.',
#     'Corporation - Business - Foreign'],
#    'ID': 111130,
#    'FILING_DATE': '10/24/2011',
#    'RECORD_NUM': '0000111500',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '312780': {'SORT_INDEX': 184,
#    'TITLE': ['XYMTEC Industries LLC',
#     'Limited Liability Company - Business - Domestic'],
#    'ID': 312780,
#    'FILING_DATE': '03/31/2021',
#    'RECORD_NUM': '0005486763',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': True,
#    'CAN_ALWAYS_FILE_AR': True,
#    'CAN_FILE_REINSTATEMENT': False},
#   '325642': {'SORT_INDEX': 185,
#    'TITLE': ['XYZ LLC', 'Limited Liability Company - Business - Domestic'],
#    'ID': 325642,
#    'FILING_DATE': '02/11/2022',
#    'RECORD_NUM': '0005700803',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False},
#   '162412': {'SORT_INDEX': 186,
#    'TITLE': ['XZILON, INC.', 'Corporation - Business - Foreign'],
#    'ID': 162412,
#    'FILING_DATE': '06/30/2017',
#    'RECORD_NUM': '0000162789',
#    'STATUS': 'Active',
#    'STANDING': 'Good Standing',
#    'ALERT': False,
#    'CAN_REINSTATE': False,
#    'CAN_FILE_AR': False,
#    'CAN_ALWAYS_FILE_AR': False,
#    'CAN_FILE_REINSTATEMENT': False}}}

# %%
keys = data["rows"].keys()

# %%
keys
# Out:
# dict_keys(['103327', '103679', '144321', '144320', '289003', '165394', '97654', '48426', '105993', '88279', '38823', '74479', '90557', '169193', '50106', '31989', '153110', '146367', '171478', '281594', '319429', '244002', '336584', '322123', '329549', '304760', '157286', '68357', '343679', '315018', '330579', '41359', '84218', '310991', '332361', '265626', '334862', '151536', '315704', '170568', '171651', '165755', '278291', '278153', '324145', '333316', '236957', '83', '64528', '1940', '330716', '333311', '171445', '311235', '111653', '180654', '108164', '339752', '279055', '302160', '278418', '288834', '305451', '279897', '338193', '141236', '344030', '344027', '335425', '314011', '274036', '169122', '333730', '313973', '282675', '135134', '154726', '148120', '275237', '17447', '73374', '62403', '269798', '100168', '117057', '14868', '74042', '337322', '136423', '333154', '326725', '293283', '47640', '136264', '290974', '123072', '294747', '280171', '270532', '280560', '328530', '316181', '343629', '279692', '85802', '270408', '66466', '335837', '116177', '125299', '123678', '273234', '315910', '323422', '49020', '309601', '333623', '231746', '86448', '304915', '282517', '154896', '291576', '107567', '90563', '45656', '337397', '169931', '159971', '159148', '265494', '342668', '173609', '188181', '196642', '299621', '282230', '341094', '160766', '321246', '254941', '151835', '91770', '328417', '180186', '275471', '310465', '157057', '308363', '76644', '171952', '13614', '269393', '169542', '77127', '195444', '273964', '333362', '337680', '83121', '236958', '309214', '309089', '333710', '92327', '79268', '106570', '108148', '154348', '337553', '318390', '319902', '259434', '228979', '132687', '231461', '319007', '240582', '278474', '323712', '100169', '9739', '138231', '111130', '312780', '325642', '162412'])

# %%
data["rows"]['103327']["TITLE"][0]
# Out:
# 'AKITA DRILLING USA CORP.'

# %%
# Storing comapany names in a list.
company_name =[]
for key in keys:
    company_name.append(data["rows"][key]["TITLE"][0])

# %%
# extract owners or agent name for each company
url = "https://firststop.sos.nd.gov/api/FilingDetail/business/"
company_owners = []
company_agents =[]
for key in keys:
    url1 = url+key+"/false"

    payload={}
    headers = {
      'authority': 'firststop.sos.nd.gov',
      'accept': '*/*',
      'accept-language': 'en-US,en;q=0.9',
      'authorization': 'undefined',
      'cookie': 'ASP.NET_SessionId=za5t3mpcb3dgqw3wrk4usgw2',
      'referer': 'https://firststop.sos.nd.gov/search/business',
      'sec-ch-ua': '"Chromium";v="104", " Not A;Brand";v="99", "Google Chrome";v="104"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }

    response = requests.request("GET", url1, headers=headers, data=payload)
    data1 = json.loads(response.text)
    if len(data1["DRAWER_DETAIL_LIST"])==10:
        company_owners.append(data1['DRAWER_DETAIL_LIST'][2]["VALUE"])
        company_agents.append("none")
    else:
        company_owners.append("none")
        company_agents.append(data1['DRAWER_DETAIL_LIST'][-1]["VALUE"])

# %%
len(company_agents),len(company_owners)
# Out:
# (187, 187)

# %%
# dictionary of lists 
dict = {"Company_ids":keys,'Company_name': company_name, 'Company_owners': company_owners, 'Company_agents': company_agents} 
    
df = pd.DataFrame(dict)

# %%
df.head(10)
# Out:
#   Company_ids                                       Company_name  \
# 0      103327                           AKITA DRILLING USA CORP.
# 1      103679                              AKITA EQUIPMENT CORP.
# 2      144321                      ATOS HEALTHCARE SERVICES, LLC
# 3      144320                  ATOS IT OUTSOURCING SERVICES, LLC
# 4      289003              Cirrata Partners Insurance Agency LLC
# 5      165394  COMCAST BROADBAND SECURITY, LLC (dba XFINITY H...
# 6       97654                    CONDUENT BUSINESS SERVICES, LLC
# 7       48426                   CONDUENT GOVERNMENT SYSTEMS, LLC
# 8      105993                          CONDUENT HR SERVICES, LLC
# 9       88279              CONDUENT HUMAN RESOURCE SERVICES, LLC
#
#   Company_owners                                     Company_agents
# 0           none  C T CORPORATION SYSTEM\n120 W SWEET AVE\nBISMA...
# 1           none  C T CORPORATION SYSTEM\n120 W SWEET AVE\nBISMA...
# 2           none  CORPORATION SERVICE COMPANY\n600 S 2ND ST\nSTE...
# 3           none  CORPORATION SERVICE COMPANY\n600 S 2ND ST\nSTE...
# 4           none  3H AGENT SERVICES, INC.\n1213 NP AVE N\nSTE 30...
# 5           none  C T CORPORATION SYSTEM\n120 W SWEET AVE\nBISMA...
# 6           none  CORPORATION SERVICE COMPANY\n600 S 2ND ST\nSTE...
# 7           none  CORPORATION SERVICE COMPANY\n600 S 2ND ST\nSTE...
# 8           none  CORPORATION SERVICE COMPANY\n600 S 2ND ST\nSTE...
# 9           none  CORPORATION SERVICE COMPANY\n600 S 2ND ST\nSTE...

# %%
# remove characters after "\n" including "\n"
df["Company_agents"] = df["Company_agents"].str.replace("(\n).*","")
df["Company_owners"] = df["Company_owners"].str.replace("(\n).*","")
# Out:
# C:\Users\sadhikari\AppData\Local\Temp\ipykernel_40684\3987945958.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Company_agents"] = df["Company_agents"].str.replace("(\n).*","")
# C:\Users\sadhikari\AppData\Local\Temp\ipykernel_40684\3987945958.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Company_owners"] = df["Company_owners"].str.replace("(\n).*","")

# %%
df.tail(20)
# Out:
#     Company_ids                        Company_name         Company_owners  \
# 167      108148         XTREME FIRE PROTECTION, LLC                   none
# 168      154348                X-TREME FITNESS, LLC                   none
# 169      337553             Xtreme installation LLC                   none
# 170      318390                Xtreme installations        David Rodriguez
# 171      319902              XTREME INVESTMENTS INC                   none
# 172      259434                     XTREME LIGHTING           CHARLES DOSH
# 173      228979                  X-TREME OUTFITTERS            COREY GULKE
# 174      132687                 XTREME PRODUCTS LLC                   none
# 175      231461              XTREME SIGNS & GRAPHIX  CRAIG NICHOLAS THOMAS
# 176      319007      Xtreme Transport Logistics LLC                   none
# 177      240582            XTREME TROPHY PROPERTIES    HAWLEY REALTY, INC.
# 178      278474                 Xtreme Xteriors LLC                   none
# 179      323712                   XTS Holdings, LLC                   none
# 180      100169          XTTRIUM LABORATORIES, INC.                   none
# 181        9739                    XXI CENTURY LTD.                   none
# 182      138231    XYLEM DEWATERING SOLUTIONS, INC.                   none
# 183      111130  XYLEM WATER SOLUTIONS U.S.A., INC.                   none
# 184      312780               XYMTEC Industries LLC                   none
# 185      325642                             XYZ LLC                   none
# 186      162412                        XZILON, INC.                   none
#
#                             Company_agents
# 167                  INCORP SERVICES, INC.
# 168                         SCOTT  SCHMIDT
# 169                       DAVID  RODRIGUEZ
# 170                                   none
# 171                 C T CORPORATION SYSTEM
# 172                                   none
# 173                                   none
# 174                            GREG  PFAFF
# 175                                   none
# 176                          MARK W WRIGHT
# 177                                   none
# 178  AAA NORTH DAKOTA REGISTERED AGENT LLC
# 179                          DARIN  POWELL
# 180                  INCORP SERVICES, INC.
# 181                          TODD J SCHULZ
# 182                 C T CORPORATION SYSTEM
# 183                 C T CORPORATION SYSTEM
# 184                        ANDREW  SANDVIK
# 185                          DAVID  SATROM
# 186            CORPORATION SERVICE COMPANY

# %%
df1 = df.copy()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company_ids     187 non-null    object
#  1   Company_name    187 non-null    object
#  2   Company_owners  187 non-null    object
#  3   Company_agents  187 non-null    object
# dtypes: object(4)
# memory usage: 6.0+ KB

# %%
df1["Company_agents_owners"] = np.where(df1["Company_owners"] == "none", df1["Company_agents"], df1["Company_owners"])

# %%
# drop unwanted columns
df1.drop(columns=['Company_owners',"Company_agents","Company_ids"], inplace=True)

# %%
df1.head(25)
# Out:
#                                          Company_name  \
# 0                            AKITA DRILLING USA CORP.
# 1                               AKITA EQUIPMENT CORP.
# 2                       ATOS HEALTHCARE SERVICES, LLC
# 3                   ATOS IT OUTSOURCING SERVICES, LLC
# 4               Cirrata Partners Insurance Agency LLC
# 5   COMCAST BROADBAND SECURITY, LLC (dba XFINITY H...
# 6                     CONDUENT BUSINESS SERVICES, LLC
# 7                    CONDUENT GOVERNMENT SYSTEMS, LLC
# 8                           CONDUENT HR SERVICES, LLC
# 9               CONDUENT HUMAN RESOURCE SERVICES, LLC
# 10             CONDUENT STATE & LOCAL SOLUTIONS, INC.
# 11                     CONDUENT STATE HEALTHCARE, LLC
# 12                          CONTRACT FREIGHTERS, INC.
# 13                   GXO LOGISTICS SUPPLY CHAIN, INC.
# 14                       GXO Logistics Worldwide, LLC
# 15            MCKESSON MEDICAL-SURGICAL MEDIMART INC.
# 16                            Miller Underground, LLC
# 17                            RingSquared Telecom LLC
# 18                     Voxtur Appraisal Services, LLC
# 19                               Voxtur Services, LLC
# 20                            X Diamond Partners, LLP
# 21                                         X ELECTRIC
# 22                                    X Golf Bismarck
# 23                                       X Golf Minot
# 24                                       X Realty LLC
#
#                Company_agents_owners
# 0             C T CORPORATION SYSTEM
# 1             C T CORPORATION SYSTEM
# 2        CORPORATION SERVICE COMPANY
# 3        CORPORATION SERVICE COMPANY
# 4            3H AGENT SERVICES, INC.
# 5             C T CORPORATION SYSTEM
# 6        CORPORATION SERVICE COMPANY
# 7        CORPORATION SERVICE COMPANY
# 8        CORPORATION SERVICE COMPANY
# 9        CORPORATION SERVICE COMPANY
# 10       CORPORATION SERVICE COMPANY
# 11       CORPORATION SERVICE COMPANY
# 12       CORPORATION SERVICE COMPANY
# 13  REGISTERED AGENT SOLUTIONS, INC.
# 14  REGISTERED AGENT SOLUTIONS, INC.
# 15       CORPORATION SERVICE COMPANY
# 16                     JARED  MILLER
# 17       CORPORATION SERVICE COMPANY
# 18               COGENCY GLOBAL INC.
# 19               COGENCY GLOBAL INC.
# 20                   KENDALL  VETTER
# 21  XTREME ELECTRICAL SERVICES, INC.
# 22                 Elite Golf 2, LLC
# 23                   Elite Golf, LLC
# 24                  ERIC  CHRISTIANS

# %%
df2 = df1.drop(df1.index[:20]) # remove companies that do not start with X.

# %%
df2.head()
# Out:
#                Company_name             Company_agents_owners
# 20  X Diamond Partners, LLP                   KENDALL  VETTER
# 21               X ELECTRIC  XTREME ELECTRICAL SERVICES, INC.
# 22          X Golf Bismarck                 Elite Golf 2, LLC
# 23             X Golf Minot                   Elite Golf, LLC
# 24             X Realty LLC                  ERIC  CHRISTIANS

# %%
# change characters to uppercase
df2["Company_name"] = df2["Company_name"].str.upper()
df2["Company_agents_owners"] = df2["Company_agents_owners"].str.upper()

# %%
len(df2["Company_name"].unique()),len(df2["Company_agents_owners"].unique())
# Out:
# (167, 111)

# %%
#Now, let us get the unique list of company_names and Company_agents_owners from our dataframe
Unique_list = list(set(df2.Company_name).union(set(df2.Company_agents_owners)))

# %%
# Initialize and add nodes
sdt_net = Network(height='750px', width='100%', bgcolor='#222222', font_color='white',notebook=True)
sdt_net.add_nodes(Unique_list)

# %%
# list of edges
my_sdt_list = df2.values.tolist()
my_sdt_list
# Out:
# [['X DIAMOND PARTNERS, LLP', 'KENDALL  VETTER'],
#  ['X ELECTRIC', 'XTREME ELECTRICAL SERVICES, INC.'],
#  ['X GOLF BISMARCK', 'ELITE GOLF 2, LLC'],
#  ['X GOLF MINOT', 'ELITE GOLF, LLC'],
#  ['X REALTY LLC', 'ERIC  CHRISTIANS'],
#  ['X REPUBLIC SALON LLC', 'PEDRO  CAVASAS'],
#  ['X S BROKERS INSURANCE AGENCY, INC.', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['X2COMM, INC.', 'NATIONAL REGISTERED AGENTS, INC.'],
#  ['X2VA LLC', 'DAKOTA W REGISTERED AGENT LLC'],
#  ['XACTLYONE FOUNDATION', 'NORTHWEST REGISTERED AGENT SERVICE, INC.'],
#  ['XACTUS, LLC', 'CORPORATION SERVICE COMPANY'],
#  ['XANADU PRODUCTS, L.L.C.', 'RICK  PAULSON'],
#  ['XANADU, LLC', 'MICHELLE  BAKKE'],
#  ['XANDER PRODUCTS & SERVICE LLC', 'ALEXANDER G. MUGAN'],
#  ['XAP CORPORATION', 'CORPORATION SERVICE COMPANY'],
#  ['XAPIC STUDIOS', 'PATRICIA A ROGALLA'],
#  ['XB INVESTMENTS, LLC', 'JOSH  JELINEK'],
#  ['XCALIBER INTERNATIONAL LTD., L.L.C.', 'CORPORATION SERVICE COMPANY'],
#  ['XCAST LABS, INC.', 'INCORP SERVICES, INC.'],
#  ['XCED AVIATION SERVICES, LLC', 'C T CORPORATION SYSTEM'],
#  ['XCEL AG SOLUTIONS LLC', 'ANTHONY  BAUMGARTNER'],
#  ['XCEL AGRONOMY LLC', 'CHRISTOPHER  PERLEBERG'],
#  ['XCEL AUTOMATION', 'XCEL AUTOMATION & ELECTRIC LLC'],
#  ['XCEL AUTOMATION & ELECTRIC LLC', 'TANNER  COLLETTE'],
#  ['XCEL AVIATION', 'TANNER S COLLETTE'],
#  ['XCEL AVIATION LLC', 'TANNER  COLLETTE'],
#  ['XCEL ENERGY', 'NORTHERN STATES POWER COMPANY'],
#  ['XCEL ENERGY INC.', 'CORPORATION SERVICE COMPANY'],
#  ['XCEL ENERGY SERVICES INC.', 'CORPORATION SERVICE COMPANY'],
#  ['XCEL ERECTORS, INC.', 'C T CORPORATION SYSTEM'],
#  ['XCEL HOLDINGS', 'TANNER COLLETTE'],
#  ['XCEL HOLDINGS LLC', 'TANNER  COLLETTE'],
#  ['XCEL NDT LLC', 'SEARCH COMPANY OF NORTH DAKOTA LLC'],
#  ['XCEL PROTECTIVE SERVICES, INC.', 'ELI  OLSON'],
#  ['XCEL TRUCKING LLC', 'KENNETH  MILLER'],
#  ['XCELL DRIVING SCHOOL LLP', 'DAVID J KLINKHAMMER'],
#  ['XCHANGE BENEFITS, LLC', '3H AGENT SERVICES, INC.'],
#  ['XCHANGE TELECOM LLC', 'INCORP SERVICES, INC.'],
#  ['XCL ASSETCO, LLC', 'C T CORPORATION SYSTEM'],
#  ['XCL MARKETING, LLC', 'C T CORPORATION SYSTEM'],
#  ['XCL RESOURCES, LLC', 'C T CORPORATION SYSTEM'],
#  ['XCL ROYALTYCO, LLC', 'C T CORPORATION SYSTEM'],
#  ['XCLOUD, LLC', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['XCLUSIVE APPAREL', 'PO BOX 2439'],
#  ['XCMG AMERICA FINANCIAL LLC', 'VCORP SERVICES, LLC'],
#  ['XCONNECT, LLC', 'INCORP SERVICES, INC.'],
#  ['XCS PROS', 'XCS PROS, LLC'],
#  ['XCS PROS, LLC', 'MICHAEL S BROOKS'],
#  ['XDATAK LLC', 'AAA NORTH DAKOTA REGISTERED AGENT LLC'],
#  ['XDP DIGITAL LLC', 'KIMBERLY  BRAUN'],
#  ['XE USA', 'CONTINENTAL EXCHANGE SOLUTIONS, INC.'],
#  ['XEBEC SYSTEMS USA LLC', 'INCORP SERVICES, INC.'],
#  ['XEBU, LLC', 'CORPORATE SERVICE CENTER, INC.'],
#  ['XECARE LLC', 'CAPITOL CORPORATE SERVICES, INC.'],
#  ['XENCOM ENERGY MANAGEMENT, LLC', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['XENEX DISINFECTION SERVICES INC.', 'INCORP SERVICES, INC.'],
#  ['XENITH, LLC', 'UNITED AGENT GROUP INC.'],
#  ['XERCOR INSURANCE SERVICES LLC', 'COGENCY GLOBAL INC.'],
#  ['XERIS PHARMACEUTICALS, INC.', 'C T CORPORATION SYSTEM'],
#  ['XEROX CORPORATION', 'THE PRENTICE-HALL CORPORATION SYSTEM, INC.'],
#  ['XEROX FINANCIAL SERVICES LLC', 'CORPORATION SERVICE COMPANY'],
#  ['XETA TECHNOLOGIES, INC.', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['XFINITY HOME', 'COMCAST BROADBAND SECURITY, LLC'],
#  ['X-GEN PHARMACEUTICALS, INC.', 'INCORP SERVICES, INC.'],
#  ['XGP PROPERTIES, LLC', 'GEORGE  POITRA'],
#  ['XH, LLC', 'CORPORATION SERVICE COMPANY'],
#  ['XIE XIE, LLC', "CINDY  O'DAY"],
#  ['XILAJU, LLC', 'JUAN  ULLOA'],
#  ['XIPHOS TECHNICAL SERVICES, LLC', 'DARIN K POWELL'],
#  ['XIULING INC', 'XIULING  WU'],
#  ['XKULSIV KICKZ LLC', 'USCA, INC.'],
#  ['XL FARMS', 'COREY K GETZLAFF'],
#  ['XL HOMES, CORP.', 'DAN  MASSETH'],
#  ['XL INDUSTRIAL SERVICES, INC.', 'CORPORATION SERVICE COMPANY'],
#  ['XL LOGISTICS LLC', 'MOHAMED  GARAAR'],
#  ['XL TRANSPORT, LLC', 'COREY  GETZLAFF'],
#  ['XLHOME, P.C. (DBA HOME HEALTH ASSESSMENTS OF NORTH DAKOTA, P.C.)',
#   'C T CORPORATION SYSTEM'],
#  ['XLT MANAGEMENT SERVICES, INC.', 'C T CORPORATION SYSTEM'],
#  ['XLT TAXI', 'X-RAY LIMA TANGO, LLC'],
#  ['XLT TRANSPORT', 'X-RAY LIMA TANGO, LLC'],
#  ['XLXF LLC', 'KIER  FUNKHOUSER'],
#  ['XM ACRES, LLP', 'MICHAEL  BERG'],
#  ['XM42', 'ROUGHRIDER ARMS LLC'],
#  ['XMODN SECURITY LLC', 'REGISTERED AGENTS INC'],
#  ['XN FINANCIAL SERVICES INC.', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['XO BEAUTY', 'ASHLEY MACK'],
#  ['XO COMMUNICATIONS SERVICES, LLC', 'C T CORPORATION SYSTEM'],
#  ['XO SKINCARE LLC', 'ANABEL  ANDRADE'],
#  ['XOME FIELD SERVICES LLC', 'CORPORATION SERVICE COMPANY'],
#  ['XOME INC.', 'CORPORATION SERVICE COMPANY'],
#  ['XOME REALTY SERVICES LLC', 'CORPORATION SERVICE COMPANY'],
#  ['XOME VALUATIONS', 'VOXTUR APPRAISAL SERVICES, LLC'],
#  ['XOXO L.L.C.', 'REGISTERED AGENTS INC'],
#  ['XOXO, PHOENIIX LLC', 'STACY  THOMAS'],
#  ['XP SYSTEMS CORPORATION', 'CORPORATION SERVICE COMPANY'],
#  ['XPERIENCE BARBERS', 'DELSON SAINTAL'],
#  ['XPERIENCE BARBERS LLC', 'DELSON  SAINTAL'],
#  ['XPERIENCE HEALTH & FITNESS', 'XPERIENCE HEALTH & FITNESS LLC'],
#  ['XPERIENCE HEALTH & FITNESS LLC', 'DARCY D REIS'],
#  ['XPERIENCE TITLE, LLC', 'COGENCY GLOBAL INC.'],
#  ['XPERT DRYWALL LLC', 'NORTHWEST REGISTERED AGENT SERVICE, INC.'],
#  ['XPERT ENTERPRISES LLC', 'RACHAEL  NADEAU'],
#  ['XPERT XTERIORS, LLC', 'PHILIP L MAENZA'],
#  ['XPI LLC', 'ERIC  OLSON'],
#  ['XPO LAST MILE, INC.', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['XPO LOGISTICS FREIGHT, INC.', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['XPO NAT SOLUTIONS, LLC', 'REGISTERED AGENT SOLUTIONS, INC.'],
#  ['XPON INTERNATIONAL LLC', 'LEGALINC CORPORATE SERVICES INC.'],
#  ['XPONET (DBA XPONET CORPORATION)', 'INCORP SERVICES, INC.'],
#  ['XPRESS BLASTING LLC', 'WILLIAM  FRANKLIN'],
#  ['XPRESS MONEY', 'MONEYDART GLOBAL SERVICES INC.'],
#  ['XPRESS PAINTING SOLUTIONS LLC', 'USCA, INC.'],
#  ['XPRESSDOCS GP, LLC', 'CORPORATION SERVICE COMPANY'],
#  ['XPRESSDOCS PARTNERS, LTD. (DBA XPRESSDOCS PARTNERS, LTD., A TEXAS LP)',
#   'CORPORATION SERVICE COMPANY'],
#  ['XPRESSDOCS PARTNERS, LTD., A TEXAS LP', '4901 N BEACH ST'],
#  ['XPT PARTNERS, LLC', '3H AGENT SERVICES, INC.'],
#  ['XQUISITE CONSTRUCTION LLC', 'BRYCE ANDERSON & ASSOCIATES, PLLC'],
#  ['XR SOLUTIONS, LLC', 'MONTGOMERY & PENDER, P.C.'],
#  ['X-RAY LIMA TANGO, LLC', 'CORY  KUNERTH'],
#  ['XRQ CORP.', 'NORTHWEST REGISTERED AGENT SERVICE, INC.'],
#  ['XS AUTOMATION', 'JEROME M HINDS'],
#  ['XS DAKOTA, LLC', 'JAMES R. BULLIS, P.C.'],
#  ['XSIDING XTERIORS LLC', 'DALE  PIETRUSZEWSKI'],
#  ['XSTREAM CLEAN CAR WASH', 'KARLGAARD ENTERPRISES, LLC'],
#  ['XSTREAM PROPERTIES, LLP', 'LYNN  JOHNSTON'],
#  ['XSTREME MD', 'LIFE LINE TECHNOLOGIES, LLC'],
#  ['XTDIRECT, LLC', 'AAA NORTH DAKOTA REGISTERED AGENT LLC'],
#  ['X-TECH LLC', 'VOGEL LAW FIRM, LTD.'],
#  ['X-TERIOR SOLUTIONS', 'TRAVIS C TOEPKE'],
#  ['XTO ENERGY INC.', 'CORPORATION SERVICE COMPANY'],
#  ['XTO HOLDINGS, LLC', 'CORPORATION SERVICE COMPANY'],
#  ['XTO OFFSHORE INC.', 'CORPORATION SERVICE COMPANY'],
#  ['XTOP LANGUAGE EDUCATION SERVICES', 'CHRISTOPHER NWACHUKWU'],
#  ['XTRA APPAREL CO LLC', 'NORTH DAKOTA REGISTERED AGENT SERVICES LLC'],
#  ['XTRA PROPERTIES, LLC', 'SHERLEEN  LARSON'],
#  ['XTRALIGHT MANUFACTURING LP', '8812 FREY RD'],
#  ['XTRA-OFFICE, INC.', 'TRACIE  DAY'],
#  ['XTRAVAGANT ELEGANCE', 'XIOMARA A. URIBE, ECATERINA M. QUINTANA'],
#  ['XTREME AUTO DETAILZ', 'SCOTT A KRAFT'],
#  ['XTREME AUTO, INC.', 'MARK L SCHUMACHER'],
#  ['XTREME BUILDERS', 'JOSH JELINEK'],
#  ['XTREME CARPET CLEANING LLC', 'ALDIN  MEHUKIC'],
#  ['X-TREME DETAILING', 'WILL A SIRY'],
#  ['X-TREME DETAILING LLC', 'WILLIAM A SIRY'],
#  ['XTREME DRILLING, LLC', 'INCORP SERVICES, INC.'],
#  ['XTREME ELECTRIC INC', 'DEREK  WANZEK'],
#  ['XTREME ELECTRICAL SERVICES, INC. (DBA X ELECTRIC)',
#   'PARACORP INCORPORATED'],
#  ['XTREME FIRE PROTECTION, LLC', 'INCORP SERVICES, INC.'],
#  ['X-TREME FITNESS, LLC', 'SCOTT  SCHMIDT'],
#  ['XTREME INSTALLATION LLC', 'DAVID  RODRIGUEZ'],
#  ['XTREME INSTALLATIONS', 'DAVID RODRIGUEZ'],
#  ['XTREME INVESTMENTS INC', 'C T CORPORATION SYSTEM'],
#  ['XTREME LIGHTING', 'CHARLES DOSH'],
#  ['X-TREME OUTFITTERS', 'COREY GULKE'],
#  ['XTREME PRODUCTS LLC', 'GREG  PFAFF'],
#  ['XTREME SIGNS & GRAPHIX', 'CRAIG NICHOLAS THOMAS'],
#  ['XTREME TRANSPORT LOGISTICS LLC', 'MARK W WRIGHT'],
#  ['XTREME TROPHY PROPERTIES', 'HAWLEY REALTY, INC.'],
#  ['XTREME XTERIORS LLC', 'AAA NORTH DAKOTA REGISTERED AGENT LLC'],
#  ['XTS HOLDINGS, LLC', 'DARIN  POWELL'],
#  ['XTTRIUM LABORATORIES, INC.', 'INCORP SERVICES, INC.'],
#  ['XXI CENTURY LTD.', 'TODD J SCHULZ'],
#  ['XYLEM DEWATERING SOLUTIONS, INC.', 'C T CORPORATION SYSTEM'],
#  ['XYLEM WATER SOLUTIONS U.S.A., INC.', 'C T CORPORATION SYSTEM'],
#  ['XYMTEC INDUSTRIES LLC', 'ANDREW  SANDVIK'],
#  ['XYZ LLC', 'DAVID  SATROM'],
#  ['XZILON, INC.', 'CORPORATION SERVICE COMPANY']]

# %%
#Now, let us add edges and viusualize our network
sdt_net.add_edges(my_sdt_list)
sdt_net.show("my_sdt_map.html")
# Out:
#         <iframe
#             width="100%"
#             height="750px"
#             src="my_sdt_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
